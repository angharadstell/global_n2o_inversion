# %% [markdown]
# # Learn how to run WOMBAT with a cutdown pseudodata example
#
# This example only includes the first three months to make it run faster and be simpler.

# %% [markdown]
# ## 1. Extract the emissions from the GEOSCHEM runs
#
# Run the process_geos_ems.py script in the cell below, this takes a couple of minutes.
#
# This script takes two arguments to allow us to make the cutdown version and the full version in the same script. The first argument is the GEOSCHEM files we want to read in, so for the full version this argument is "HEMCO_diagnostics.??????010000.nc". In the cutdown case, we only want the first three months, so the first argument is "HEMCO_diagnostics.20100[1-3]010000.nc". The second argument is what to save the emissions output as, here it is "monthly_fluxes_pseudo.nc", in the full version it is "monthly_fluxes.nc".

# %%
# %run ../intermediates/process_geos_ems.py "HEMCO_diagnostics.20100[1-3]010000.nc" "monthly_fluxes_pseudo.nc"
# Out:
# Loading data from HEMCO_diagnostics.20100[1-3]010000.nc
# Saving data to monthly_fluxes_pseudo.nc
# /work/as16992/geoschem/N2O/output/base
# [PosixPath('/work/as16992/geoschem/N2O/output/base/HEMCO_diagnostics.201001010000.nc'), PosixPath('/work/as16992/geoschem/N2O/output/base/HEMCO_diagnostics.201002010000.nc'), PosixPath('/work/as16992/geoschem/N2O/output/base/HEMCO_diagnostics.201003010000.nc')]
# /work/as16992/geoschem/N2O/output/201001
# [PosixPath('/work/as16992/geoschem/N2O/output/201001/HEMCO_diagnostics.201001010000.nc'), PosixPath('/work/as16992/geoschem/N2O/output/201001/HEMCO_diagnostics.201002010000.nc'), PosixPath('/work/as16992/geoschem/N2O/output/201001/HEMCO_diagnostics.201003010000.nc')]
# /work/as16992/geoschem/N2O/output/201002
# [PosixPath('/work/as16992/geoschem/N2O/output/201002/HEMCO_diagnostics.201002010000.nc'), PosixPath('/work/as16992/geoschem/N2O/output/201002/HEMCO_diagnostics.201003010000.nc')]
# /work/as16992/geoschem/N2O/output/201003
# ...

# %% [markdown]
# Have a look at output file
